# %%
import json
from numpy import genfromtxt
import csv
import numpy as np

# %%
r_u = {}
with open("/Users/yuyanzhang/Desktop/CMU/10605/yelp/10805-YelpChallenge/dataset/user.json",'r') as f:
    for line in f:
        line = json.loads(line)
        uid = line['user_id']

        credit = line['useful']+line['compliment_photos']+line['compliment_list']+line['compliment_funny']+line['funny']
        +line['compliment_note']+line['compliment_plain']+line['compliment_writer']+line['compliment_cute']
        +line['compliment_more']+line['compliment_hot']+line['cool']+line['compliment_profile']+line['compliment_cool']
        r_u[uid] = [line['yelping_since'], credit, line['review_count'], line['friends'], line['fans'], line['average_stars'], line['elite']]
        
        
        print(r_u[uid])
        break
# Out:
# [u'2010-07-13', 46705, 272, [u'M19NwFwAXKRZzt8koF11hQ', u'QRcMZ8pJJBBZaKubHOoMDQ', u'uimsjcHoBnXz1MAKGvB26w', u'v325XGF-l9da74ZMWEjyoA', u'vP5ajc1oGURsNvCXewsnDw', u'9nSutZOliE9Vg4XVGEx1HA', u'--2vR0DIsmQ6WfcSzKWigw', u'LDJ51sk5SJXovRI2yQZimA', u'3R_dB9VQ_D3WPJEw7pmorA', u'8drMKNHWavs2g6uf0pLtvg', u'wOGfOjBaP-lCS1NW_En2LQ', u'AK2-Pvb6E9vgeXWyY4Jxog', u'DbUSCSMQwD3eiAre0Ueu8A', u'B_2qev6exPELs7ZnO4iljg', u'LQALTuDeCRLwR9NOxUWS5A', u'kSUU18CH2BRPLK1uUsz1Wg', u'M-HINGCHOnaQkKq8WDtRMA', u'9lWyDOySHcc6Jiqp2-EPUw', u'j2Eu9pE22Rp_DRoSp3KgQg', u'neuz9oCcHiW4k-jltcC1BA', u'PRQxRp1IFHPBlbXeDwG3mA', u't9vCxltuXJ941V8ppWVsVQ', u'pYK8JuBylomxLIwwyv0Iyw', u'WTLPH3jIWOUTFMpD4o_7Vg', u'qAE5pJYa75gRbpC7bgI3Ow', u'7OxFrOWLP04hSCGY_g3aUw', u'nRdfX_I0CaOq7lJunJMPpA', u'W81-CPVrM9c6F8XiNuEUvA', u'VaVkC537R46xRNpOucRgvA', u'j8YxElKHhbg1ghQDSI1v3Q', u'sYLXiL6q8eiB-D4e3LfWaw', u'6ueSDFjnsnr-ypVR15WTRg', u'Mi1VEqRHfJ75ESxPuAV9MQ', u'itz3iIH8qPpm0RowHZ63cA', u'Wc5L6iuvSNF5WGBlqIO8nw', u'zb_83ib91kA6jBislfTSoQ
# ...
